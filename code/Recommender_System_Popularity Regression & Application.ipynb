# %% [markdown]
# # Popularity Prediction

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import sklearn.metrics as sm
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error

from xgboost import XGBRegressor
from sklearn.model_selection import cross_val_score
import xgboost as xgb

from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# ## Train and Test Data

# %%
X_train = pd.read_csv('x_train_popularity.csv')
X_test = pd.read_csv('x_test_popularity.csv')
y_train = pd.read_csv('y_train_popularity.csv')
y_test = pd.read_csv('y_test_popularity.csv')

# %%
y_train = X_train['popularity_target']
y_test = X_test['popularity_target']
X_train = X_train.drop(columns = ['popularity_target'],axis = 1)
X_test = X_test.drop(columns = ['popularity_target'],axis = 1)
[X_train.shape, y_train.shape, X_test.shape, y_test.shape]
# Out:
# [(175770, 49), (175770,), (58590, 49), (58590,)]

# %%
X_train.shape
# Out:
# (175770, 49)

# %%
X_train.columns
# Out:
# Index(['acousticness', 'danceability', 'duration_ms', 'energy', 'explicit',
#        'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
#        'speechiness', 'tempo', 'valence', 'songname_noneng',
#        'num_words_in_songname', 'acousticness_year', 'danceability_year',
#        'duration_ms_year', 'energy_year', 'instrumentalness_year',
#        'liveness_year', 'loudness_year', 'speechiness_year', 'tempo_year',
#        'valence_year', 'key_year', 'mode_year', 'acousticness_artist',
#        'danceability_artist', 'duration_ms_artist', 'energy_artist',
#        'instrumentalness_artist', 'liveness_artist', 'loudness_artist',
#        'speechiness_artist', 'tempo_artist', 'valence_artist', 'key_artist',
#        'mode_artist', 'count_artist', 'period_1920_to_1950',
#        'period_1950_to_1980', 'period_1980_to_2000', 'period_2000_to_2010',
#        'period_2010_to_2020', 'num_artists_grp_numart_1',
#        'num_artists_grp_numart_2', 'num_artists_grp_numart_3',
#        'num_artists_grp_numart_4_above'],
#       dtype='object')

# %% [markdown]
# ## Regression

# %% [markdown]
# ### 1. Linear Regression

# %%
#X = data_reg.drop(columns = ['popularity_target'],axis = 1)
#y = data_reg['popularity_target']
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)
lr_model = LinearRegression()
lr_model.fit(X_train, y_train)
lr_y_predict = lr_model.predict(X_test)
training_accuracy = lr_model.score(X_train,y_train)
test_accuracy = lr_model.score(X_test,y_test)
print('lr_y_predict:', lr_y_predict)
# Out:
# lr_y_predict: [3.63848433 1.04207685 1.04602914 ... 3.21853119 3.72945463 3.13514288]

# %%
training_accuracy = lr_model.score(X_train,y_train)
print('training accuracy:', training_accuracy)
# Out:
# training accuracy: 0.5930892194611539

# %%
test_accuracy = lr_model.score(X_test,y_test)
print('testing accuracy:', test_accuracy)
# Out:
# testing accuracy: 0.5921086591418128

# %%
r2_score(y_test, lr_y_predict)
# Out:
# 0.5921086591418128

# %% [markdown]
# ### 1.1 Linear Regression -- Grid Search

# %%
parameters = {'fit_intercept':[True,False], 'normalize':[True,False], 'copy_X':[True, False]}
grid = GridSearchCV(lr_model,parameters, cv=None)
grid.fit(X_train, y_train)
print ("r2 / variance : ", grid.best_score_)
print("Residual sum of squares: %.2f"
              % np.mean((grid.predict(X_test) - y_test) ** 2))
# Out:
# r2 / variance :  0.5928209552956973
# Residual sum of squares: 0.83

# %%
grid.predict(X_train)
print('training accuracy:', r2_score(y_train, grid.predict(X_train)))
# Out:
# training accuracy: 0.5930892194611539

# %%
grid.predict(X_test)
print("testing accuracy:", r2_score(y_test, grid.predict(X_test)))
# Out:
# testing accuracy: 0.592108659141712

# %% [markdown]
# ### 2. Gradient Boosting

# %%
gb_model = GradientBoostingRegressor(max_depth=4, n_estimators=200, random_state=42)
gb_model.fit(X_train, y_train)
gb_y_predict = gb_model.predict(X_test)
gb_model.score(X_train, y_train)
gb_model.score(X_test, y_test)
print('gb_y_predict:', gb_y_predict)
# Out:
# gb_y_predict: [3.72868502 0.84829503 1.16975416 ... 3.70536779 5.04286808 3.31985748]

# %% [markdown]
# ### 3. XGB

# %%
xgbr = xgb.XGBRegressor(verbosity=0) 

xgbr.fit(X_train, y_train)
score = xgbr.score(X_train, y_train)  
ypred = xgbr.predict(X_test)
mse = mean_squared_error(y_test, ypred)
r2_score(ypred, y_test, multioutput='variance_weighted')
print("MSE: %.2f" % mse)
print("RMSE: %.2f" % (mse**(1/2.0)))

# %% [markdown]
# ### 4. SVM -- Took forever to run, didn't get the result

# %%
from sklearn import svm
svm_model = svm.SVC(kernel = 'rbf', C = 30, gamma = 'auto')
svm_model.fit(X_train, y_train)
svm_model.score(X_test, y_test)

# %% [markdown]
# # Application

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import sklearn.metrics as sm
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error

from xgboost import XGBRegressor
from sklearn.model_selection import cross_val_score
import xgboost as xgb

from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# #### 1. Load master dataset

# %%
data = pd.read_csv('data_final_popularity.csv')

# %%
data.columns
# Out:
# Index(['acousticness', 'artists', 'danceability', 'duration_ms', 'energy',
#        'explicit', 'id', 'instrumentalness', 'key', 'liveness', 'loudness',
#        'mode', 'name', 'speechiness', 'tempo', 'valence', 'year',
#        'artist_list', 'num_artists_grp', 'songname_noneng',
#        'num_words_in_songname', 'period', 'artist_song_id',
#        'acousticness_year', 'danceability_year', 'duration_ms_year',
#        'energy_year', 'instrumentalness_year', 'liveness_year',
#        'loudness_year', 'speechiness_year', 'tempo_year', 'valence_year',
#        'key_year', 'mode_year', 'acousticness_artist', 'danceability_artist',
#        'duration_ms_artist', 'energy_artist', 'instrumentalness_artist',
#        'liveness_artist', 'loudness_artist', 'speechiness_artist',
#        'tempo_artist', 'valence_artist', 'key_artist', 'mode_artist',
#        'count_artist', 'popularity_target'],
#       dtype='object')

# %%
#col_to_dummy = ['period', 'num_artists_grp']
data = pd.get_dummies(data = data, columns=['period', 'num_artists_grp'])
data.columns
# Out:
# Index(['acousticness', 'artists', 'danceability', 'duration_ms', 'energy',
#        'explicit', 'id', 'instrumentalness', 'key', 'liveness', 'loudness',
#        'mode', 'name', 'speechiness', 'tempo', 'valence', 'year',
#        'artist_list', 'songname_noneng', 'num_words_in_songname',
#        'artist_song_id', 'acousticness_year', 'danceability_year',
#        'duration_ms_year', 'energy_year', 'instrumentalness_year',
#        'liveness_year', 'loudness_year', 'speechiness_year', 'tempo_year',
#        'valence_year', 'key_year', 'mode_year', 'acousticness_artist',
#        'danceability_artist', 'duration_ms_artist', 'energy_artist',
#        'instrumentalness_artist', 'liveness_artist', 'loudness_artist',
#        'speechiness_artist', 'tempo_artist', 'valence_artist', 'key_artist',
#        'mode_artist', 'count_artist', 'popularity_target',
#        'period_1920_to_1950', 'period_1950_to_1980', 'period_1980_to_2000',
#        'period_2000_to_2010', 'period_2010_to_2020',
#        'num_artists_grp_numart_1', 'num_artists_grp_numart_2',
#        'num_artists_grp_numart_3', 'num_artists_grp_numart_4_above'],
#       dtype='object')

# %%
data.shape
# Out:
# (234372, 56)

# %% [markdown]
# #### 2. Load training and testing datasets

# %%
X_train = pd.read_csv('x_train_popularity.csv')
X_test = pd.read_csv('x_test_popularity.csv')
y_train = pd.read_csv('y_train_popularity.csv')
y_test = pd.read_csv('y_test_popularity.csv')

# %%
print("X_train info:")
print(X_train.shape)
print(X_train.columns)
print()

print("y_train info:")
print(y_train.shape)
print(y_train.columns)
print()

print("X_test info:")
print(X_test.shape)
print(X_test.columns)
print()

print("y_test info:")
print(y_test.shape)
print(y_test.columns)
# Out:
# X_train info:
# (175770, 50)
# Index(['acousticness', 'danceability', 'duration_ms', 'energy', 'explicit',
#        'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
#        'speechiness', 'tempo', 'valence', 'songname_noneng',
#        'num_words_in_songname', 'acousticness_year', 'danceability_year',
#        'duration_ms_year', 'energy_year', 'instrumentalness_year',
#        'liveness_year', 'loudness_year', 'speechiness_year', 'tempo_year',
#        'valence_year', 'key_year', 'mode_year', 'acousticness_artist',
#        'danceability_artist', 'duration_ms_artist', 'energy_artist',
#        'instrumentalness_artist', 'liveness_artist', 'loudness_artist',
#        'speechiness_artist', 'tempo_artist', 'valence_artist', 'key_artist',
#        'mode_artist', 'count_artist', 'popularity_target',
#        'period_1920_to_1950', 'period_1950_to_1980', 'period_1980_to_2000',
#        'period_2000_to_2010', 'period_2010_to_2020',
#        'num_artists_grp_numart_1', 'num_artists_grp_numart_2',
#        'num_artists_grp_numart_3', 'num_artists_grp_numart_4_above'],
#       dtype='object')
#
# y_train info:
# (175770, 1)
# Index(['popularity_target'], dtype='object')
#
# X_test info:
# (58590, 50)
# Index(['acousticness', 'danceability', 'duration_ms', 'energy', 'explicit',
#        'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
#        'speechiness', 'tempo', 'valence', 'songname_noneng',
#        'num_words_in_songname', 'acousticness_year', 'danceability_year',
#        'duration_ms_year', 'energy_year', 'instrumentalness_year',
#        'liveness_year', 'loudness_year', 'speechiness_year', 'tempo_year',
#        'valence_year', 'key_year', 'mode_year', 'acousticness_artist',
#        'danceability_artist', 'duration_ms_artist', 'energy_artist',
#        'instrumentalness_artist', 'liveness_artist', 'loudness_artist',
#        'speechiness_artist', 'tempo_artist', 'valence_artist', 'key_artist',
#        'mode_artist', 'count_artist', 'popularity_target',
#        'period_1920_to_1950', 'period_1950_to_1980', 'period_1980_to_2000',
#        'period_2000_to_2010', 'period_2010_to_2020',
#        'num_artists_grp_numart_1', 'num_artists_grp_numart_2',
#        'num_artists_grp_numart_3', 'num_artists_grp_numart_4_above'],
#       dtype='object')
#
# y_test info:
# (58590, 1)
# Index(['popularity_target'], dtype='object')

# %% [markdown]
# #### 3. Create training and testing dataframes for modeling

# %%
#col_to_exclude = ['artist_song_id', 'artists', 'artist_list', 'id', 'name', 'year']
#target_var = 'popularity_target

#X = data.drop(columns = ['popularity_target', 'artist_song_id', 'artists', 'artist_list', 'id', 'name', 'year'],axis = 1)
X = data.drop(columns = ['popularity_target'],axis = 1)
y = data['popularity_target']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
print(X.shape)
print(y.shape)
# Out:
# (234372, 55)
# (234372,)

# %%
X_real_train = X_train.drop(columns = ['artist_song_id', 'artists', 'artist_list', 'id', 'name', 'year'],axis = 1)
X_real_train
# Out:
#         acousticness  danceability  duration_ms  energy  explicit  \
# 62309        0.84300         0.148       237293  0.3040         0
# 32016        0.97000         0.559       191707  0.1420         0
# 43654        0.66700         0.463       247409  0.5120         0
# 32400        0.99500         0.789       177408  0.1060         0
# 90798        0.25600         0.513       290400  0.5440         0
# ...              ...           ...          ...     ...       ...
# 176963       0.91300         0.528       235773  0.3590         0
# 117952       0.10600         0.569       123587  0.4250         0
# 173685       0.77700         0.722       176040  0.6890         0
# 43567        0.00185         0.533       253960  0.9240         0
# 199340       0.81300         0.330       265440  0.0686         0
#
#         instrumentalness  key  liveness  loudness  mode  ...  count_artist  \
# 62309           0.827000    8    0.0959   -16.175     1  ...         286.0
# 32016           0.927000    5    0.1210   -15.550     1  ...          48.0
# 43654           0.000129    8    0.0815    -7.305     1  ...         111.0
# 32400           0.441000    7    0.1860   -14.662     0  ...           9.0
# 90798           0.000000    0    0.0862    -7.300     0  ...         192.0
# ...                  ...  ...       ...       ...   ...  ...           ...
# 176963          0.850000    5    0.2010   -10.415     1  ...          18.0
# 117952          0.000000    9    0.2750   -12.670     1  ...          26.0
# 173685          0.000000    3    0.6040    -7.516     1  ...           8.0
# 43567           0.185000    6    0.3730   -11.679     0  ...          94.0
# 199340          0.000002   10    0.1180   -18.536     1  ...        1435.0
#
#         period_1920_to_1950  period_1950_to_1980  period_1980_to_2000  \
# 62309                     0                    1                    0
# 32016                     1                    0                    0
# 43654                     0                    0                    1
# 32400                     1                    0                    0
# 90798                     0                    1                    0
# ...                     ...                  ...                  ...
# 176963                    0                    1                    0
# 117952                    0                    0                    1
# 173685                    0                    1                    0
# 43567                     0                    0                    1
# 199340                    0                    1                    0
#
#         period_2000_to_2010  period_2010_to_2020  num_artists_grp_numart_1  \
# 62309                     0                    0                         1
# 32016                     0                    0                         1
# 43654                     0                    0                         0
# 32400                     0                    0                         1
# 90798                     0                    0                         1
# ...                     ...                  ...                       ...
# 176963                    0                    0                         0
# 117952                    0                    0                         1
# 173685                    0                    0                         0
# 43567                     0                    0                         1
# 199340                    0                    0                         1
#
#         num_artists_grp_numart_2  num_artists_grp_numart_3  \
# 62309                          0                         0
# 32016                          0                         0
# 43654                          1                         0
# 32400                          0                         0
# 90798                          0                         0
# ...                          ...                       ...
# 176963                         1                         0
# 117952                         0                         0
# 173685                         1                         0
# 43567                          0                         0
# 199340                         0                         0
#
#         num_artists_grp_numart_4_above
# 62309                                0
# 32016                                0
# 43654                                0
# 32400                                0
# 90798                                0
# ...                                ...
# 176963                               0
# 117952                               0
# 173685                               0
# 43567                                0
# 199340                               0
#
# [175779 rows x 49 columns]

# %%
X_real_test = X_test.drop(columns = ['artist_song_id', 'artists', 'artist_list', 'id', 'name', 'year'],axis = 1)
X_real_test
# Out:
#         acousticness  danceability  duration_ms  energy  explicit  \
# 104429      0.963000         0.202       219613  0.0445         0
# 227545      0.846000         0.594       256307  0.0626         0
# 126434      0.975000         0.528       182987  0.2880         0
# 35186       0.987000         0.198       444880  0.2260         0
# 84647       0.994000         0.359       171818  0.0364         0
# ...              ...           ...          ...     ...       ...
# 178945      0.801000         0.290       243640  0.3300         0
# 204364      0.000034         0.264       315667  0.9280         0
# 11455       0.582000         0.228       141840  0.3580         0
# 1120        0.975000         0.622       202760  0.1550         0
# 194741      0.779000         0.504       186133  0.1470         0
#
#         instrumentalness  key  liveness  loudness  mode  ...  count_artist  \
# 104429          0.780000    2    0.3470   -30.649     0  ...          30.0
# 227545          0.000000    7    0.1060   -16.298     1  ...           7.0
# 126434          0.011300    5    0.0972   -12.759     1  ...        3179.0
# 35186           0.155000    5    0.3620   -12.531     1  ...         250.0
# 84647           0.914000    0    0.0627   -24.188     1  ...          62.0
# ...                  ...  ...       ...       ...   ...  ...           ...
# 178945          0.000724    3    0.1140   -11.307     1  ...        1003.0
# 204364          0.571000   11    0.1750   -13.599     1  ...          34.0
# 11455           0.000003    5    0.1290    -7.161     1  ...          34.0
# 1120            0.000000    4    0.2600   -16.196     1  ...           4.0
# 194741          0.000000    9    0.2490   -23.045     1  ...          30.0
#
#         period_1920_to_1950  period_1950_to_1980  period_1980_to_2000  \
# 104429                    1                    0                    0
# 227545                    0                    0                    1
# 126434                    1                    0                    0
# 35186                     0                    1                    0
# 84647                     0                    1                    0
# ...                     ...                  ...                  ...
# 178945                    0                    1                    0
# 204364                    0                    0                    1
# 11455                     0                    1                    0
# 1120                      1                    0                    0
# 194741                    0                    1                    0
#
#         period_2000_to_2010  period_2010_to_2020  num_artists_grp_numart_1  \
# 104429                    0                    0                         0
# 227545                    0                    0                         1
# 126434                    0                    0                         0
# 35186                     0                    0                         0
# 84647                     0                    0                         0
# ...                     ...                  ...                       ...
# 178945                    0                    0                         1
# 204364                    0                    0                         1
# 11455                     0                    0                         1
# 1120                      0                    0                         1
# 194741                    0                    0                         0
#
#         num_artists_grp_numart_2  num_artists_grp_numart_3  \
# 104429                         1                         0
# 227545                         0                         0
# 126434                         1                         0
# 35186                          0                         0
# 84647                          1                         0
# ...                          ...                       ...
# 178945                         0                         0
# 204364                         0                         0
# 11455                          0                         0
# 1120                           0                         0
# 194741                         0                         0
#
#         num_artists_grp_numart_4_above
# 104429                               0
# 227545                               0
# 126434                               0
# 35186                                1
# 84647                                0
# ...                                ...
# 178945                               0
# 204364                               0
# 11455                                0
# 1120                                 0
# 194741                               1
#
# [58593 rows x 49 columns]

# %%
print(X_real_train.shape)
print(X_real_test.shape)

# %% [markdown]
# #### 4. Run gradient boosting model and find the predicted values

# %%
gb_model = GradientBoostingRegressor(max_depth=4, n_estimators=200, random_state=42)
gb_model.fit(X_real_train, y_train)

gb_y_test = gb_model.predict(X_real_test)
gb_y_train = gb_model.predict(X_real_train)

print('gb_y_test:', gb_y_test)
print('gb_y_train:', gb_y_train)
# Out:
# gb_y_test: [1.1828935  4.37726246 1.01026774 ... 2.63365833 1.32789927 1.03590927]
# gb_y_train: [2.7733698  1.57484786 4.05264807 ... 1.38076138 3.85250491 3.5592157 ]

# %%
print('train accuracy:', gb_model.score(X_real_train, y_train))
print('test accuracy:', gb_model.score(X_real_test, y_test))
# Out:
# train accuracy: 0.7620910154040665
# test accuracy: 0.7571456187325651

# %% [markdown]
# #### 5. Attach results back to the master dataset

# %%
# Round popularity predicted
round_test = gb_y_test.round().astype(int)
roudn_train = gb_y_train.round().astype(int)

# Create dataframes and save popularity into them
test_output = pd.DataFrame(data = gb_y_test, columns = ['predicted_popularity'])
test_output['popularity_group'] = pd.DataFrame(data = round_test)

train_output = pd.DataFrame(data = gb_y_train, columns = ['predicted_popularity'])
train_output['popularity_group'] = pd.DataFrame(data = roudn_train)

# %%
# Combine with the datasets
X_test['predicted_popularity'] = test_output['predicted_popularity']
X_test['popularity_group'] = test_output['popularity_group']

X_train['predicted_popularity'] = train_output['predicted_popularity']
X_train['popularity_group'] = train_output['popularity_group']
# Out:
# C:\Users\xiaoc\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\xiaoc\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\xiaoc\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\xiaoc\anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
X_train.shape
# Out:
# (175779, 57)

# %%
# combine two dataframes
all_data = pd.concat([X_test, X_train], axis=0)
# Output results
all_data.to_csv('all_popularity.csv', index = False)

# %%
all_data.head()
# Out:
#         acousticness                                            artists  \
# 104429         0.963    ['Richard Strauss', 'Bavarian State Orchestra']
# 227545         0.846                                      ['Tsai Chin']
# 126434         0.975             ['Francisco Canaro', 'Eduardo Adrian']
# 35186          0.987  ['Giacomo Puccini', 'Maria Callas', 'Nicolai G...
# 84647          0.994             ['Claude Debussy', 'Walter Gieseking']
#
#         danceability  duration_ms  energy  explicit                      id  \
# 104429         0.202       219613  0.0445         0  7xU1KumXHBCXABmkYg722C
# 227545         0.594       256307  0.0626         0  2KjgqLUhkmEkXCXicj7iFP
# 126434         0.528       182987  0.2880         0  5OmHEO46I13khn9Kf1g4Hu
# 35186          0.198       444880  0.2260         0  2pqaM7qZVySU9q1I58kXhp
# 84647          0.359       171818  0.0364         0  07O6boPfQDWRzYmVR0N5o7
#
#         instrumentalness  key  liveness  ...  period_1950_to_1980  \
# 104429            0.7800    2    0.3470  ...                    0
# 227545            0.0000    7    0.1060  ...                    0
# 126434            0.0113    5    0.0972  ...                    0
# 35186             0.1550    5    0.3620  ...                    1
# 84647             0.9140    0    0.0627  ...                    1
#
#         period_1980_to_2000 period_2000_to_2010  period_2010_to_2020  \
# 104429                    0                   0                    0
# 227545                    1                   0                    0
# 126434                    0                   0                    0
# 35186                     0                   0                    0
# 84647                     0                   0                    0
#
#         num_artists_grp_numart_1  num_artists_grp_numart_2  \
# 104429                         0                         1
# 227545                         1                         0
# 126434                         0                         1
# 35186                          0                         0
# 84647                          0                         1
#
#         num_artists_grp_numart_3 num_artists_grp_numart_4_above  \
# 104429                         0                              0
# 227545                         0                              0
# 126434                         0                              0
# 35186                          0                              1
# 84647                          0                              0
#
#         predicted_popularity  popularity_group
# 104429                   NaN               NaN
# 227545                   NaN               NaN
# 126434                   NaN               NaN
# 35186               1.341113               1.0
# 84647                    NaN               NaN
#
# [5 rows x 57 columns]

# %% [markdown]
# # Recommendation

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
input_data = pd.read_csv('pre.csv')

# %%
input_data['cluster_labels'][input_data.artists == '2NE1']
# Out:
# 29    5
# Name: cluster_labels, dtype: int64

# %%
input_data.shape
# Out:
# (8301, 15)

# %%
input_data.artists
# Out:
# 0       "Joseph And The Amazing Technicolor Dreamcoat"...
# 1                                     "Weird Al" Yankovic
# 2                                            'Til Tuesday
# 3                  (Con La Participación de Marc Anthony)
# 4                                              (Hed) P.E.
#                               ...
# 8296                                                  陈昭伶
# 8297                                                  陳秀男
# 8298                                                  颜薇恩
# 8299                                                  麥志誠
# 8300                                                  龔詩嘉
# Name: artists, Length: 8301, dtype: object

# %%
all_data = pd.read_csv('all_popularity.csv')

# %%
all_data.shape
# Out:
# (234372, 57)

# %%
all_data.name
# Out:
# 0         Don Quixote Op.35: VI Variation V: The Knight’...
# 1                                       恰似你的溫柔 - Remastered
# 2                        Amando en Silencio - Remasterizado
# 3         Puccini: Madama Butterfly, Act 1: "Vogliatemi ...
# 4         Debussy: 12 Études, CD 143, L. 136: No. 1, Pou...
#                                 ...
# 234367                                          Night Rider
# 234368                                 No Hay Dedos Iguales
# 234369                                            Jambalaya
# 234370                                        Tommy The Cat
# 234371                                       All Or Nothing
# Name: name, Length: 234372, dtype: object

# %%
all_data.artist_list
# Out:
# 0                        Bavarian State Orchestra
# 1                                       Tsai Chin
# 2                                Francisco Canaro
# 3         Orchestra Del Teatro Alla Scala, Milano
# 4                                Walter Gieseking
#                            ...
# 234367                               Eddie Sauter
# 234368                           Beto Quintanilla
# 234369                            Sally Sweetland
# 234370                                     Primus
# 234371                              Frank Sinatra
# Name: artist_list, Length: 234372, dtype: object

# %%
combined = input_data.merge(all_data, left_on='artists', right_on='artist_list')[['artists_x', 'artist_list', 'name', 'predicted_popularity', 'popularity_group']]

# %%
combined = input_data.merge(all_data, 
                            left_on='artists', 
                            right_on='artist_list')[['artists_x', 'artist_list', 'name', 
                                                     'predicted_popularity', 'popularity_group']]
combined
# Out:
#                                                artists_x  \
# 0      "Joseph And The Amazing Technicolor Dreamcoat"...
# 1      "Joseph And The Amazing Technicolor Dreamcoat"...
# 2      "Joseph And The Amazing Technicolor Dreamcoat"...
# 3      "Joseph And The Amazing Technicolor Dreamcoat"...
# 4                                    "Weird Al" Yankovic
# ...                                                  ...
# 68188                                                陳秀男
# 68189                                                陳秀男
# 68190                                                颜薇恩
# 68191                                                麥志誠
# 68192                                                龔詩嘉
#
#                                              artist_list  \
# 0      "Joseph And The Amazing Technicolor Dreamcoat"...
# 1      "Joseph And The Amazing Technicolor Dreamcoat"...
# 2      "Joseph And The Amazing Technicolor Dreamcoat"...
# 3      "Joseph And The Amazing Technicolor Dreamcoat"...
# 4                                    "Weird Al" Yankovic
# ...                                                  ...
# 68188                                                陳秀男
# 68189                                                陳秀男
# 68190                                                颜薇恩
# 68191                                                麥志誠
# 68192                                                龔詩嘉
#
#                                  name  predicted_popularity  popularity_group
# 0                   Go, Go, Go Joseph                   NaN               NaN
# 1                   Any Dream Will Do              3.603946               4.0
# 2              Close Every Door To Me                   NaN               NaN
# 3      Jacob And Sons / Joseph's Coat                   NaN               NaN
# 4                      Happy Birthday                   NaN               NaN
# ...                               ...                   ...               ...
# 68188                              選擇                   NaN               NaN
# 68189                           瀟灑走一回                   NaN               NaN
# 68190               祝你 Happy New Year                   NaN               NaN
# 68191                         難為正邪定分界              3.715483               4.0
# 68192                  My Island Home              4.661587               5.0
#
# [68193 rows x 5 columns]

# %%
combined.artists_x.nunique()
# Out:
# 8301

# %%
# Only based on artists
#artist_popularity = combined.groupby('artists_x').mean('predicted_popularity')
#artist_popularity

# %%
artist_popularity = combined.groupby(['artists_x', 'name']).mean('predicted_popularity')
artist_popularity.head(10)
# Out:
#                                                                                                        predicted_popularity  \
# artists_x                                          name
# "Joseph And The Amazing Technicolor Dreamcoat" ... Any Dream Will Do                                               3.603946
#                                                    Close Every Door To Me                                               NaN
#                                                    Go, Go, Go Joseph                                                    NaN
#                                                    Jacob And Sons / Joseph's Coat                                       NaN
# "Weird Al" Yankovic                                (This Song's Just) Six Words Long                               5.201951
#                                                    Addicted to Spuds                                                    NaN
#                                                    Albuquerque                                                          NaN
#                                                    Amish Paradise (Parody of "Gangsta's Paradise" ...              2.455375
#                                                    Another One Rides the Bus                                       0.571289
#                                                    Bohemian Polka                                                  1.099822
#
#                                                                                                        popularity_group
# artists_x                                          name
# "Joseph And The Amazing Technicolor Dreamcoat" ... Any Dream Will Do                                                4.0
#                                                    Close Every Door To Me                                           NaN
#                                                    Go, Go, Go Joseph                                                NaN
#                                                    Jacob And Sons / Joseph's Coat                                   NaN
# "Weird Al" Yankovic                                (This Song's Just) Six Words Long                                5.0
#                                                    Addicted to Spuds                                                NaN
#                                                    Albuquerque                                                      NaN
#                                                    Amish Paradise (Parody of "Gangsta's Paradise" ...               2.0
#                                                    Another One Rides the Bus                                        1.0
#                                                    Bohemian Polka                                                   1.0

# %%
artist_popularity.sort_values(by=['predicted_popularity'], ascending = False).head()
# Out:
#                                                           predicted_popularity  \
# artists_x        name
# Dailey & Vincent Cumberland River                                     5.747432
# Funkadelic       Maggot Brain                                         5.649359
# Jwonder          Dirty S Hwy                                          5.592359
# Interpol         C'mere                                               5.563474
# Michael Jackson  Liberian Girl - 2012 Remastered Version              5.560343
#
#                                                           popularity_group
# artists_x        name
# Dailey & Vincent Cumberland River                                      6.0
# Funkadelic       Maggot Brain                                          6.0
# Jwonder          Dirty S Hwy                                           6.0
# Interpol         C'mere                                                6.0
# Michael Jackson  Liberian Girl - 2012 Remastered Version               6.0

# %% [markdown]
# # Output

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### 1. Read test and train files

# %%
X_train = pd.read_csv('x_train_popularity.csv')
X_test = pd.read_csv('x_test_popularity.csv')
y_train = pd.read_csv('y_train_popularity.csv')
y_test = pd.read_csv('y_test_popularity.csv')

# %%
y_train = X_train['popularity_target']
y_test = X_test['popularity_target']
X_train = X_train.drop(columns = ['popularity_target'],axis = 1)
X_test = X_test.drop(columns = ['popularity_target'],axis = 1)
[X_train.shape, y_train.shape, X_test.shape, y_test.shape]
# Out:
# [(175770, 49), (175770,), (58590, 49), (58590,)]

# %% [markdown]
# #### 2. Fit in the gradient boosting model

# %%
gb_model = GradientBoostingRegressor(max_depth=4, n_estimators=200, random_state=42)
gb_model.fit(X_train, y_train)

# Get popularity predicted
gb_y_test = gb_model.predict(X_test)
gb_y_train = gb_model.predict(X_train)
print('gb_y_test:', gb_y_test)
print('gb_y_train:', gb_y_train)
# Out:
# gb_y_test: [3.72868502 0.84829503 1.16975416 ... 3.70536779 5.04286808 3.31985748]
# gb_y_train: [3.61372389 1.58944808 3.20849484 ... 3.36884802 1.11285303 0.67874693]

# %%
# Round popularity predicted
round_test = gb_y_test.round().astype(int)
roudn_train = gb_y_train.round().astype(int)

# %%
# Create dataframes and save popularity into them
test_output = pd.DataFrame(data = gb_y_test, columns = ['predicted_popularity'])
test_output['popularity_group'] = pd.DataFrame(data = round_test)

train_output = pd.DataFrame(data = gb_y_train, columns = ['predicted_popularity'])
train_output['popularity_group'] = pd.DataFrame(data = roudn_train)

# %%
# Combine with the datasets
X_test['predicted_popularity'] = test_output['predicted_popularity']
X_test['popularity_group'] = test_output['popularity_group']

X_train['predicted_popularity'] = train_output['predicted_popularity']
X_train['popularity_group'] = train_output['popularity_group']

# %%
X_test
# Out:
#        acousticness  danceability  duration_ms  energy  explicit  \
# 0          0.249000         0.561       225480   0.636         0
# 1          0.000456         0.506       320014   0.974         0
# 2          0.739000         0.434        36040   0.438         0
# 3          0.796000         0.627       167960   0.317         0
# 4          0.000138         0.416       194520   0.819         0
# ...             ...           ...          ...     ...       ...
# 58585      0.987000         0.461        79400   0.214         0
# 58586      0.020300         0.740       232440   0.849         0
# 58587      0.840000         0.725       231907   0.362         0
# 58588      0.067300         0.569       214363   0.865         1
# 58589      0.068200         0.543       222413   0.750         0
#
#        instrumentalness  key  liveness  loudness  mode  ...  \
# 0              0.003600    0    0.0588    -9.525     1  ...
# 1              0.958000   10    0.9440    -6.599     0  ...
# 2              0.879000    4    0.3560   -18.721     1  ...
# 3              0.000000    8    0.1840   -12.787     1  ...
# 4              0.001080    9    0.1220    -3.974     1  ...
# ...                 ...  ...       ...       ...   ...  ...
# 58585          0.000000    2    0.5190   -13.182     1  ...
# 58586          0.000004   10    0.3460    -3.205     1  ...
# 58587          0.181000    7    0.1060   -12.424     1  ...
# 58588          0.000000    4    0.3120    -3.844     0  ...
# 58589          0.016600    2    0.1250    -7.071     0  ...
#
#        period_1950_to_1980  period_1980_to_2000  period_2000_to_2010  \
# 0                        1                    0                    0
# 1                        0                    0                    0
# 2                        0                    0                    0
# 3                        1                    0                    0
# 4                        0                    0                    1
# ...                    ...                  ...                  ...
# 58585                    0                    0                    0
# 58586                    0                    0                    1
# 58587                    0                    0                    0
# 58588                    0                    0                    0
# 58589                    0                    0                    0
#
#        period_2010_to_2020  num_artists_grp_numart_1  \
# 0                        0                         1
# 1                        1                         1
# 2                        0                         0
# 3                        0                         0
# 4                        0                         1
# ...                    ...                       ...
# 58585                    0                         0
# 58586                    0                         1
# 58587                    1                         1
# 58588                    1                         0
# 58589                    1                         1
#
#        num_artists_grp_numart_2  num_artists_grp_numart_3  \
# 0                             0                         0
# 1                             0                         0
# 2                             0                         0
# 3                             1                         0
# 4                             0                         0
# ...                         ...                       ...
# 58585                         0                         0
# 58586                         0                         0
# 58587                         0                         0
# 58588                         1                         0
# 58589                         0                         0
#
#        num_artists_grp_numart_4_above  predicted_popularity  popularity_group
# 0                                   0              3.728685                 4
# 1                                   0              0.848295                 1
# 2                                   1              1.169754                 1
# 3                                   0              2.740016                 3
# 4                                   0              4.297614                 4
# ...                               ...                   ...               ...
# 58585                               1              1.046192                 1
# 58586                               0              4.318287                 4
# 58587                               0              3.705368                 4
# 58588                               0              5.042868                 5
# 58589                               0              3.319857                 3
#
# [58590 rows x 51 columns]

# %%
X_train
# Out:
#         acousticness  danceability  duration_ms  energy  explicit  \
# 0           0.743000         0.558       281134   0.282         0
# 1           0.799000         0.204       294800   0.227         0
# 2           0.614000         0.366       151133   0.788         0
# 3           0.194000         0.805       321649   0.858         1
# 4           0.168000         0.579       266173   0.874         0
# ...              ...           ...          ...     ...       ...
# 175765      0.901000         0.565       180000   0.309         0
# 175766      0.961000         0.174       429227   0.092         0
# 175767      0.000149         0.177       226280   0.962         0
# 175768      0.926000         0.500       170400   0.299         0
# 175769      0.002440         0.789       426155   0.676         0
#
#         instrumentalness  key  liveness  loudness  mode  ...  \
# 0               0.000000    8    0.0651   -17.901     1  ...
# 1               0.879000    0    0.2140   -12.959     0  ...
# 2               0.000036    9    0.1230    -7.001     1  ...
# 3               0.000008    0    0.2560    -3.067     1  ...
# 4               0.001060    1    0.0749    -7.248     0  ...
# ...                  ...  ...       ...       ...   ...  ...
# 175765          0.735000    0    0.1370   -19.260     0  ...
# 175766          0.801000    5    0.1340   -20.070     1  ...
# 175767          0.068000    9    0.9530    -6.298     1  ...
# 175768          0.838000    2    0.3680    -9.251     1  ...
# 175769          0.017300   11    0.0572    -7.593     0  ...
#
#         period_1950_to_1980  period_1980_to_2000  period_2000_to_2010  \
# 0                         1                    0                    0
# 1                         1                    0                    0
# 2                         1                    0                    0
# 3                         0                    0                    0
# 4                         0                    1                    0
# ...                     ...                  ...                  ...
# 175765                    1                    0                    0
# 175766                    0                    0                    0
# 175767                    1                    0                    0
# 175768                    0                    0                    0
# 175769                    0                    0                    0
#
#         period_2010_to_2020  num_artists_grp_numart_1  \
# 0                         0                         0
# 1                         0                         0
# 2                         0                         1
# 3                         1                         0
# 4                         0                         1
# ...                     ...                       ...
# 175765                    0                         1
# 175766                    0                         0
# 175767                    0                         1
# 175768                    0                         0
# 175769                    1                         0
#
#         num_artists_grp_numart_2  num_artists_grp_numart_3  \
# 0                              0                         1
# 1                              1                         0
# 2                              0                         0
# 3                              0                         0
# 4                              0                         0
# ...                          ...                       ...
# 175765                         0                         0
# 175766                         1                         0
# 175767                         0                         0
# 175768                         1                         0
# 175769                         0                         1
#
#         num_artists_grp_numart_4_above  predicted_popularity  popularity_group
# 0                                    0              3.613724                 4
# 1                                    0              1.589448                 2
# 2                                    0              3.208495                 3
# 3                                    1              2.785609                 3
# 4                                    0              3.799443                 4
# ...                                ...                   ...               ...
# 175765                               0              3.475318                 3
# 175766                               0              1.158789                 1
# 175767                               0              3.368848                 3
# 175768                               0              1.112853                 1
# 175769                               0              0.678747                 1
#
# [175770 rows x 51 columns]

# %%
# Output results
X_test.to_csv('test_output.csv', index = False)
X_train.to_csv('train_output.csv', index = False)
